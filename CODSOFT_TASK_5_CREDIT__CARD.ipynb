# %% [markdown]
# <a href="https://colab.research.google.com/github/vignesh2k03/CODSOFT-/blob/main/CODSOFT_TASK_5_CREDIT__CARD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# DATA PROCESSING

# %%
# Loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Last 5 rows of the dataset
credit_card_data.tail()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 7967  10980 -0.046786  0.030050  2.037794 -0.670130 -0.727283 -0.588537
# 7968  10980  1.284388 -0.013181  0.646174  0.198985 -0.568675 -0.526121
# 7969  10981  1.190428 -0.122329  0.954945  0.267101 -0.971026 -0.652279
# 7970  10981 -0.725175  0.298202  1.824761 -2.587170  0.283605 -0.016617
# 7971  10981  1.226153 -0.129645  0.735197  0.142752 -0.703245 -0.349641
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 7967 -0.067966 -0.370767  0.228931  ...  0.264364  1.078896 -0.097768
# 7968 -0.448235 -0.167709  1.773223  ... -0.101868 -0.030298 -0.081412
# 7969 -0.612992 -0.003909  1.633117  ... -0.015001  0.127027  0.012079
# 7970  0.153659  0.045084 -0.197611  ... -0.017097 -0.070535 -0.442861
# 7971 -0.612641  0.020507  1.648986  ... -0.047936  0.040196 -0.057391
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7973 entries, 0 to 7972
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    7973 non-null   int64
#  1   V1      7973 non-null   float64
#  2   V2      7973 non-null   float64
#  3   V3      7973 non-null   float64
#  4   V4      7973 non-null   float64
#  5   V5      7973 non-null   float64
#  6   V6      7973 non-null   float64
#  7   V7      7973 non-null   float64
#  8   V8      7973 non-null   float64
#  9   V9      7973 non-null   float64
#  10  V10     7973 non-null   float64
#  11  V11     7973 non-null   float64
#  12  V12     7973 non-null   float64
#  13  V13     7973 non-null   float64
#  14  V14     7973 non-null   float64
#  15  V15     7972 non-null   float64
#  16  V16     7972 non-null   float64
#  17  V17     7972 non-null   float64
#  18  V18     7972 non-null   float64
#  19  V19     7972 non-null   float64
# ...

# %%
# Checking the number of missing values in each column
credit_card_data.dropna(inplace=True)
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Distribution of legit transaction & fraudlent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    7947
# 1.0      25
# Name: Class, dtype: int64

# %% [markdown]
# THE DATASET IS HIGHLY INBALANCED

# %% [markdown]
# 0-> NORMAL TRANSACTION

# %% [markdown]
# 1-> FRAUD TRANSACTION

# %%
# Separatingthe data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (7947, 31)
# (25, 31)

# %%
legit.Amount.describe()
# Out:
# count    7947.000000
# mean       65.284891
# std       194.126547
# min         0.000000
# 25%         4.795000
# 50%        15.950000
# 75%        54.990000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      25.000000
# mean      106.308400
# std       372.676883
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    4246.546496 -0.297235  0.286979  0.917142  0.201968 -0.023263
# 1.0    7359.240000 -1.154048  2.930880 -4.757618  4.590240 -0.636103
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.164019 -0.019547 -0.072779  0.662196  ...  0.042418 -0.055123
# 1.0   -1.952536 -2.202403  0.647916 -1.581984  ...  0.263011  0.393614
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.165485 -0.034918  0.026636  0.088960  0.019511  0.014875  0.000417
# 1.0   -0.265715 -0.116502 -0.183413  0.067479  0.256994  0.421586  0.237600
#
#            Amount
# Class
# 0.0     65.284891
# 1.0    106.308400
#
# [2 rows x 30 columns]

# %% [markdown]
# UNDER SAMPLING

# %% [markdown]
# BUILD A SIMILAR DATASET CONTAINING SIMILAR DISTRIBUTION OF NORMAL TRANSACTIONS AND FRAUD TRANSACTION

# %% [markdown]
# NUMBER OF FRADULENT TRANSACTIONS -->25

# %%
legit_sample = legit.sample(n=25)

# %% [markdown]
# CONCATENATING TWO DATAFRAMES

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5948  6585  0.120374 -1.851031  1.792637  2.632953 -1.528636  2.255683
# 6987  9130  0.596842 -1.211524  0.707544 -0.670130 -0.485238  1.698287
# 182    118  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256
# 2027  1573 -2.258102  1.306719  1.390339  1.568776 -1.087489  0.699806
# 1912  1472 -0.845734  0.817315  1.209917 -0.891733  0.257661  0.029742
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5948 -1.141083  0.685180  2.340793  ...  0.239812  0.432055 -0.387534
# 6987 -0.839038  0.559518  2.761186  ...  0.289989  0.986057 -0.196347
# 182   0.086781 -0.202836  0.035154  ... -0.287592 -0.832682  0.128083
# 2027 -0.553315  1.076076  1.224964  ... -0.471114 -0.641939 -0.027864
# 1912  0.524041  0.182016  0.251089  ... -0.188065 -0.501912 -0.256047
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 6870  8757 -1.863756  3.442644 -4.468260  2.805336 -2.118412 -2.332285
# 6882  8808 -4.617217  1.695694 -3.114372  4.328199 -1.873257 -0.989908
# 6899  8878 -2.661802  5.856393 -7.653616  6.379742 -0.060712 -3.131550
# 6903  8886 -2.535852  5.793644 -7.618463  6.395830 -0.065210 -3.136372
# 6971  9064 -3.499108  0.258555 -4.489558  4.853894 -6.974522  3.628382
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 6870 -4.261237  1.701682 -1.439396  ...  0.667927 -0.516242 -0.012218
# 6882 -4.577265  0.472216  0.472017  ...  0.481830  0.146023  0.117039
# 6899 -3.103570  1.778492 -3.831154  ...  0.734775 -0.435901 -0.384766
# 6903 -3.104557  1.823233 -3.878658  ...  0.716720 -0.448060 -0.402407
# 6971  5.431271 -1.946734 -0.775680  ... -1.052368  0.204817 -2.119007
#
#            V24       V25       V26       V27       V28   Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    25
# 1.0    25
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#           Time        V1       V2        V3        V4        V5        V6  \
# Class
# 0.0    4983.56  0.393063 -0.04218  0.929531  0.724843 -0.465832  0.490187
# 1.0    7359.24 -1.154048  2.93088 -4.757618  4.590240 -0.636103 -1.952536
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.600054  0.101178  1.138243  ... -0.049271  0.036578 -0.256868
# 1.0   -2.202403  0.647916 -1.581984  ...  0.263011  0.393614 -0.265715
#
#             V23       V24       V25       V26       V27       V28    Amount
# Class
# 0.0   -0.115115 -0.107524  0.152110  0.218575  0.045635  0.036846   73.6896
# 1.0   -0.116502 -0.183413  0.067479  0.256994  0.421586  0.237600  106.3084
#
# [2 rows x 30 columns]

# %% [markdown]
# SPLITTING THE DATA IN TO FEATURES AND VARIABLES

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 5948   6585  0.120374 -1.851031  1.792637  2.632953 -1.528636  2.255683
# 6987   9130  0.596842 -1.211524  0.707544 -0.670130 -0.485238  1.698287
# 182     118  1.254914  0.350287  0.302488  0.693114 -0.371470 -1.070256
# 2027   1573 -2.258102  1.306719  1.390339  1.568776 -1.087489  0.699806
# 1912   1472 -0.845734  0.817315  1.209917 -0.891733  0.257661  0.029742
# 2828   2404 -0.861488  1.143829  0.745212 -0.972180  0.387083  0.052228
# 6226   7278  1.120659 -0.065313  0.798026  0.991009 -0.518320  0.101179
# 4857   4359 -1.948641  1.839684  1.085546 -0.853739  0.606312  0.762124
# 6859   8733  1.189241 -0.963839  1.173571 -0.280265 -1.496529  0.023192
# 6933   8999  1.147011 -0.262460  0.899833  0.877679 -0.592413  0.337163
# 3059   2619  1.195016  0.203954  0.620039  0.648622 -0.462717 -0.712698
# 6845   8683  1.113653 -0.010614  0.862979  0.985177 -0.466818  0.136385
# ...

# %%
print(Y)
# Out:
# 5948    0.0
# 6987    0.0
# 182     0.0
# 2027    0.0
# 1912    0.0
# 2828    0.0
# 6226    0.0
# 4857    0.0
# 6859    0.0
# 6933    0.0
# 3059    0.0
# 6845    0.0
# 3967    0.0
# 4968    0.0
# 247     0.0
# 4689    0.0
# 7031    0.0
# 4088    0.0
# 7610    0.0
# 2084    0.0
# 7089    0.0
# 2937    0.0
# 4749    0.0
# 6458    0.0
# 1905    0.0
# 541     1.0
# 623     1.0
# 4920    1.0
# 6108    1.0
# 6329    1.0
# 6331    1.0
# 6334    1.0
# 6336    1.0
# 6338    1.0
# 6427    1.0
# 6446    1.0
# 6472    1.0
# 6529    1.0
# 6609    1.0
# 6641    1.0
# 6717    1.0
# 6719    1.0
# 6734    1.0
# 6774    1.0
# 6820    1.0
# 6870    1.0
# 6882    1.0
# 6899    1.0
# 6903    1.0
# 6971    1.0
# Name: Class, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (50, 30) (40, 30) (10, 30)

# %% [markdown]
# MODEL TRAINING

# %% [markdown]
# LOGISTIC REGRESSION

# %%
model = LogisticRegression()

# %%
# Training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# MODEL EVALUATION

# %%
# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data: ', training_data_accuracy)
# Out:
# Accuracy on Training data:  1.0

# %%
# Accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data: ', test_data_accuracy)
# Out:
# Accuracy score on Test Data:  1.0
